# %%
print("Hello world")
# Out:
# Hello world

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # 1. 구글 코랩 기초 사용법
#
# 맥북은 cmd 윈도우는 ctrl
#   1.(필수) ctrl + Enter : 해당 셀 실행
#
#   2.(필수) Alt(option) + Enter:해당 셀 실행 + 코드 블록 하단 추가
#
#   3.(필수) ctrl + M A : 코드 셀위에 삽입
#
#   4.ctrl + M Y : 코드 셀로 변경
#
#   5.ctrl + M M : 마크다운 셀로 변경
#
#   ![2023-11-28 (4).png](data:image/png;base64,...)6.ctrl + M Z : 실행 취소

# %% [markdown]
# # 수정 관련된 단축키
#
# 1.Ctrl(Command) + Alt(Option) + 화살표위아래 : 동시 수정
# 2.자주 쓰는 예시 필요
#
# 3.(자주) Ctrl(Command) + D : 같은 단어 찾아 동시 수정
#
# Ctrl(Command) + Shift + L : 동일 단어를 전체로 찾아 동시 수정
#
# Alt(Option) + Shift + 화살표위아래 : 해당내용을 위나 아래 복사해서 붙여넣기
#
# Alt(Option) + 화살표위아래 : 해당 내용을 위나 아래로 보내기
#
# (자주) Ctrl(Command) + Alt(Option) + 화살표위아래 : 위아래 동시 수정
#
# (자주) Home, End : 문장의 양 끝
#
# (필수) Ctrl + / : 주석
#
# (필수) Shift(cmd) + Del : 한 줄 지우기
#
# (필수) Tab, Ctrl + ] : 들여쓰기
#
# (필수) Shift + Tab, Ctrl + [ : 내어쓰기

# %%
# 데이터셋 불러오기
import pandas as pd
data = pd.read_csv("example_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-505a45659fc3> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("example_dataset.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
mean_age = data['age'].mean()
mean_height = data['height'].mean()
mean_weight = data['weight'].mean()

print("Average Age:", mean_age)
print("Average Height:", mean_height)
print("Average Weight:", mean_weight)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-95150875ce17> in <cell line: 1>()
# ----> 1 mean_age = data['age'].mean()
#       2 mean_height = data['height'].mean()
#       3 mean_weight = data['weight'].mean()
#       4
#       5 print("Average Age:", mean_age)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
data = pd.read_csv("example_dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-505a45659fc3> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data = pd.read_csv("example_dataset.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# # 4. 마크다운
# ## 4.1 헤더
# ### 4.1.1 사용법
# 제목을 입력하는 기능

# %% [markdown]
# ## 4.2 강조
#
# 이 내용은 *강조* 해야하는 **문장**입니다.
# 강조
# *강조*
# **강조**

# %% [markdown]
# ## 4.3 목록(Lists)
#
# 1. 순서 1번
# 2. 순서 2번
# 3. 순서 3번
#
# * 순서 없는 것 1
# * 순서 없는 것 2
# * 순서 없는 것 3

# %% [markdown]
# # 4.4 링크
#
# * 사용법: [텍스트](URL): 형식을 사용하여 하이퍼링크를 삽입합니다.
#
# * [pyalgo](https://www.google.com/search?q=%ED%8C%8C%EC%9D%B4%EC%95%8C%EA%B3%A0&sca_esv=594335904&sxsrf=AM9HkKnrDk1kusenDqtK-j0sOMjX60_6Fw%3A1703813363135&ei=8yCOZfj1B6zY1e8P7bKwuAU&udm=&ved=0ahUKEwi4u5eyv7ODAxUsbPUHHW0ZDFcQ4dUDCBA&uact=5&oq=%ED%8C%8C%EC%9D%B4%EC%95%8C%EA%B3%A0&gs_lp=...&sclient=gws-wiz-serp)

# %% [markdown]
# # 4.5 이미지
#
# * 사용법: ![대체 텍스트](이미지 URL) 형식을 사용하여 이미지를 삽입합니다. 대체텍스트는 이미지가 표시되지 않을때 나타납니다
#
# ![캥거루](https://ichef.bbci.co.uk/news/1024/branded_korean/E309/production/_104712185__104711426_rogerkangaroo2.jpg)

# %% [markdown]
# # 4.6 코드
#
# * 인라인 코드:`를 사용하여 텍스트 내에 코드를 삽입합니다
# - **코드 블록**:여러 줄의 코드를 나타낼 때는 **`````**를 사용하여 코드 블록을 생성합니다
#
# `````print("hello world")`````

# %% [markdown]
# # 4.7 기타
#
# * 취소선 ~~취소선~~
# ---
# * 인용문
# > 인용문 1 입니다.
# >> 인용문 1-1입니다.
# ---
# * 구분선
# ---
